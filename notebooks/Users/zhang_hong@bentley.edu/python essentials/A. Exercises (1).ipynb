# %% [markdown]
# # Exercises for Python Essentials

# %% [markdown]
# ## Contents
# 1. Data Lab notebooks
# 2. Exercises

# %% [markdown]
# ## 1. Data Lab notebooks
#
# The techniques to be used in these exercises can be found in the notebook links listed below.
# In addition reference links are provided for each exercise.
#
# - [Basics](https://bentley.cloud.databricks.com/#notebook/90445/command/90446)
# - [Lists](https://bentley.cloud.databricks.com/#notebook/90524/command/90525)
# - [Tuples](https://bentley.cloud.databricks.com/#notebook/90494/command/90495)
# - [Dictionaries](https://bentley.cloud.databricks.com/#notebook/90420/command/857727)
# - [JSON](https://bentley.cloud.databricks.com/#notebook/858024/command/858122)
# - [Comprehensions](https://bentley.cloud.databricks.com/#notebook/90595)
# - [Map, Filter, Reduce](https://bentley.cloud.databricks.com/#notebook/90384/command/90385)
#
# All links are to notebooks on the Bentley Databricks cluster. Links to GitHub will be provided as soon as possible.

# %% [markdown]
# ## 2. Exercises

# %% [markdown]
# #### Python classes & objects
# __Exercise:__ use three (string) methods on the string defined below and describe your results.
#
# Reference: [Basics](https://bentley.cloud.databricks.com/#notebook/90445/command/90446)

# %%
# %python
my_string = "It's a lovely day in the neighborhood."
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Put your code in the cell below. Notice that it starts with `%python `.

# %%
# %python
dir(my_string)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>
# [&apos;__add__&apos;,
#  &apos;__class__&apos;,
#  &apos;__contains__&apos;,
#  &apos;__delattr__&apos;,
#  &apos;__dir__&apos;,
#  &apos;__doc__&apos;,
#  &apos;__eq__&apos;,
#  &apos;__format__&apos;,
#  &apos;__ge__&apos;,
#  &apos;__getattribute__&apos;,
#  &apos;__getitem__&apos;,
#  &apos;__getnewargs__&apos;,
#  &apos;__gt__&apos;,
#  &apos;__hash__&apos;,
#  &apos;__init__&apos;,
#  &apos;__iter__&apos;,
#  &apos;__le__&apos;,
#  &apos;__len__&apos;,
#  &apos;__lt__&apos;,
#  &apos;__mod__&apos;,
#  &apos;__mul__&apos;,
# ...

# %% [markdown]
# #### Python classes & objects
# __Exercise:__ use three (list) methods on the list defined below and describe your results.
#
# Reference: [Lists](https://bentley.cloud.databricks.com/#notebook/90524/command/90525)

# %%
# %python
my_list = [2, 3, 4, 5, 7, 8, 11, 16]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
dir(my_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>
# [&apos;__add__&apos;,
#  &apos;__class__&apos;,
#  &apos;__contains__&apos;,
#  &apos;__delattr__&apos;,
#  &apos;__delitem__&apos;,
#  &apos;__dir__&apos;,
#  &apos;__doc__&apos;,
#  &apos;__eq__&apos;,
#  &apos;__format__&apos;,
#  &apos;__ge__&apos;,
#  &apos;__getattribute__&apos;,
#  &apos;__getitem__&apos;,
#  &apos;__gt__&apos;,
#  &apos;__hash__&apos;,
#  &apos;__iadd__&apos;,
#  &apos;__imul__&apos;,
#  &apos;__init__&apos;,
#  &apos;__iter__&apos;,
#  &apos;__le__&apos;,
#  &apos;__len__&apos;,
#  &apos;__lt__&apos;,
# ...

# %% [markdown]
# Put your code in the cell below. Notice that it starts with `%python `.

# %%
# %python

# %% [markdown]
# #### Python basics
# __Exercise:__ Write code to confirm that:
# 1. `"e r"` is a substring of `"data science research lab"` (your code will return `True`)
# 1. `[1,2]` is not an element of the list `[1,2,3]` (your code will return `False`)
#
# Reference: [Lists](https://bentley.cloud.databricks.com/#notebook/90524/command/90525)

# %%
# %python 
"e r" in "data science research lab"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>True
# </div>

# %%
# %python
[1,2] in [1,2,3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>False
# </div>

# %% [markdown]
# #### JSON data format

# %% [markdown]
# ##### Construct a JSON object
# __Exercise:__ Create JSON data (which is a string) that contains (fake) contact info for three people.
# Store this string in the variable `group_json_string` below.
# - In the following exercises this data will create a list and each element of the list will be a dictionary.
# - Each dictionary should record the contact info for one person and should include a key called `"name"`.
#
# Reference: [JSON in Python](https://bentley.cloud.databricks.com/#notebook/858024/command/858122)

# %%
# %python
import json
group_json_string='[{"name": "name1","contact":"name1@gmail.com"},{"name": "name2","contact":"name2@gmail.com"},{"name": "name3","contact":"name3@gmail.com"}]'
my_json = json.loads(group_json_string)
my_json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">44</span><span class="ansired">]: </span>
# [{&apos;name&apos;: &apos;name1&apos;, &apos;contact&apos;: &apos;name1@gmail.com&apos;},
#  {&apos;name&apos;: &apos;name2&apos;, &apos;contact&apos;: &apos;name2@gmail.com&apos;},
#  {&apos;name&apos;: &apos;name3&apos;, &apos;contact&apos;: &apos;name3@gmail.com&apos;}]
# </div>

# %% [markdown]
# ##### Create a list from JSON data
# __Exercise:__ convert the JSON data stored in `group_json_string` from the previous exercise into a list using the `loads` function from the `json` library
#
# Reference: [pandas - Series](https://bentley.cloud.databricks.com/#notebook/89774/command/89775) (fix link)

# %%
# %python

# %% [markdown]
# ##### Create a dataframe from a list of dictionaries
# __Exercise:__ create a Pandas dataframe using the JSON data, stored in `group_json_string`, from the previous exercise
# - use the pandas dataframe constructor to do so
# - complete the code cell below be replacing `___` with your code
#
# Reference:- [pandas - Indexing & Selecting data](https://bentley.cloud.databricks.com/#notebook/561178/command/561179)

# %%
# %python 
pd.DataFrame(___)

# %% [markdown]
# ##### Create a list from JSON data stored in a file
# __Exercise:__ load the JSON data stored in the file `/dbfs/mnt/datalab-datasets/file-samples/one_list.json` into the variable `one_list` using the `load` function from the `json` library
#
# The contents of this variable will be used in exercises below.
#
# Reference: TBD

# %% [markdown]
# #### Python lists

# %% [markdown]
# There are two ways to work with lists and dictionaries in Python:
# 1. using list and dictionary omprehensions
# 1. using the `map` and `filter` functions
#
# There is a subsection for each below. Both exercises use the contents of the `one_list` variable created above.

# %% [markdown]
# In both of the next two exercises use the vector of values from the quantity field, created above.

# %% [markdown]
# ##### Comprehensions
# __Exercise__: Create three results using a list comprehension
# 1. a list of quantities from each dictionary listed in `one_string`
# 1. a list where each element is a quantity plus `100`
# 1. a list where each element is a quantity plus `100`, but only for quantities that are greater than `250`
#
# Reference: [Comprehensions](https://bentley.cloud.databricks.com/#notebook/90595/command/90596)

# %% [markdown]
# ##### Functions `map` & `filter`
# __Exercise__: Create two results using the `map` function
# 1. a list of quantities from each dictionary listed in `one_string`
# 1. a list where each element is a quantity plus `100`
#
# Reference:- [Map, Filter, Reduce](https://bentley.cloud.databricks.com/#notebook/90384/command/90385)

# %% [markdown]
# ##### Functions `map` & `filter`
# __Exercise__: Create a result using the `map` function
# 1. a list where each element is a quantity plus `100`, but only for quantities that are greater than `250`
#
#
# Reference: [Map, Filter, Reduce](https://bentley.cloud.databricks.com/#notebook/90384/command/90385)

# %% [markdown]
# __The End__
